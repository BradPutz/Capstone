# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('C:/Users/bradl/Documents/Code/Capstone Project/Potential Datasets/Broadway 1.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51743 entries, 0 to 51742
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SHOW              51743 non-null  object
#  1   THEATER           51743 non-null  object
#  2   THIS WEEK GROSS   51743 non-null  object
#  3   POTENTIAL GROSS   46559 non-null  object
#  4   AVG TICKET PRICE  51743 non-null  object
#  5   TOP TICKET PRICE  51116 non-null  object
#  6   SEATS SOLD        51743 non-null  object
#  7   SEATS IN THEATER  51743 non-null  object
#  8   PERFORMANCES      51743 non-null  int64
#  9   PREVIEWS          51743 non-null  int64
#  10  CAPACITY %        51743 non-null  object
#  11  WEEK DATE         51743 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 4.7+ MB

# %%
df1.head(5)
# Out:
#                  SHOW                    THEATER THIS WEEK GROSS  \
# 0              Wicked           Gershwin Theatre   $2,435,631.00
# 1       The Outsiders  Bernard B. Jacobs Theatre   $1,306,481.95
# 2       The Lion King           Minskoff Theatre   $1,543,557.10
# 3    The Great Gatsby           Broadway Theatre   $1,056,897.21
# 4  The Book of Mormon     Eugene O'Neill Theatre     $835,677.45
#
#   POTENTIAL GROSS AVG TICKET PRICE TOP TICKET PRICE SEATS SOLD  \
# 0             NaN          $158.08          $352.00     15,408
# 1             NaN          $156.75          $497.00      8,335
# 2             NaN          $116.91          $267.00     13,203
# 3             NaN           $96.95          $277.00     10,902
# 4             NaN          $103.48            $0.00      8,076
#
#   SEATS IN THEATER  PERFORMANCES  PREVIEWS CAPACITY %   WEEK DATE
# 0            1,926             8         0    100.00%  2025-03-09
# ...

# %%
df1.describe()
# Out:
#        PERFORMANCES      PREVIEWS
# count  51743.000000  51743.000000
# mean       7.228611      0.583171
# std        2.236832      1.920554
# min        0.000000      0.000000
# 25%        8.000000      0.000000
# 50%        8.000000      0.000000
# 75%        8.000000      0.000000
# max       17.000000     16.000000

# %%
df1['THEATER'].unique()
# Out:
# array(['Gershwin Theatre', 'Bernard B. Jacobs Theatre',
#        'Minskoff Theatre', 'Broadway Theatre', "Eugene O'Neill Theatre",
#        'St. James Theatre', 'Lena Horne Theatre', 'Nederlander Theatre',
#        'Helen Hayes Theater', 'Ethel Barrymore Theatre',
#        'John Golden Theatre', 'Lyceum Theatre', 'Al Hirschfeld Theatre',
#        'Neil Simon Theatre', 'Belasco Theatre', 'Sam S. Shubert Theatre',
#        'Lyric Theatre', 'Richard Rodgers Theatre', 'Walter Kerr Theatre',
#        'Majestic Theatre', 'Lunt-Fontanne Theatre', 'Ambassador Theatre',
#        'August Wilson Theatre', 'Gerald Schoenfeld Theatre',
#        'New Amsterdam Theatre', 'Stephen Sondheim Theatre',
#        'Todd Haimes Theatre', 'Studio 54', 'Circle in the Square Theatre',
#        'Samuel J. Friedman Theatre', 'Hudson Theatre',
#        'James Earl Jones Theatre', 'Music Box Theatre', 'Marquis Theatre',
#        'Winter Garden Theatre', 'Longacre Theatre', 'Broadhurst Theatre',
# ...

# %%
df1['THEATER'].nunique()
# Out:
# 62

# %%
df1['SHOW'].nunique()
# Out:
# 1215

# %%
df1 = df1.drop(['POTENTIAL GROSS'],axis = 1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51743 entries, 0 to 51742
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SHOW              51743 non-null  object
#  1   THEATER           51743 non-null  object
#  2   THIS WEEK GROSS   51743 non-null  object
#  3   AVG TICKET PRICE  51743 non-null  object
#  4   TOP TICKET PRICE  51116 non-null  object
#  5   SEATS SOLD        51743 non-null  object
#  6   SEATS IN THEATER  51743 non-null  object
#  7   PERFORMANCES      51743 non-null  int64
#  8   PREVIEWS          51743 non-null  int64
#  9   CAPACITY %        51743 non-null  object
#  10  WEEK DATE         51743 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 4.3+ MB

# %%
df1['AVG TICKET PRICE'] = df1['AVG TICKET PRICE'].str.replace('$','')
df1['AVG TICKET PRICE'] = df1['AVG TICKET PRICE'].astype('float64')

# %%
df1['TOP TICKET PRICE'] = df1['TOP TICKET PRICE'].str.replace('$','').str.replace(',','')
df1['TOP TICKET PRICE'] = df1['TOP TICKET PRICE'].astype('float64')

# %%
df1['THIS WEEK GROSS'] = df1['THIS WEEK GROSS'].str.replace('$','').str.replace(',','')
df1['THIS WEEK GROSS'] = df1['THIS WEEK GROSS'].astype('float64')

# %%
df1['SEATS SOLD'] = df1['SEATS SOLD'].str.replace(',','')
df1['SEATS SOLD'] = df1['SEATS SOLD'].astype('int64')

# %%
df1['SEATS IN THEATER'] = df1['SEATS IN THEATER'].str.replace(',','')
df1['SEATS IN THEATER'] = df1['SEATS IN THEATER'].astype('int64')

# %%
df1['CAPACITY %'] = df1['CAPACITY %'].str.rstrip('%').astype(float) / 100

# %%
df1['WEEK DATE'] = pd.to_datetime(df1['WEEK DATE'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51743 entries, 0 to 51742
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SHOW              51743 non-null  object
#  1   THEATER           51743 non-null  object
#  2   THIS WEEK GROSS   51743 non-null  float64
#  3   AVG TICKET PRICE  51743 non-null  float64
#  4   TOP TICKET PRICE  51116 non-null  float64
#  5   SEATS SOLD        51743 non-null  int64
#  6   SEATS IN THEATER  51743 non-null  int64
#  7   PERFORMANCES      51743 non-null  int64
#  8   PREVIEWS          51743 non-null  int64
#  9   CAPACITY %        51743 non-null  float64
#  10  WEEK DATE         51743 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(4), object(2)
# memory usage: 4.3+ MB

# %%
df1.head(5)
# Out:
#                  SHOW                    THEATER  THIS WEEK GROSS  \
# 0              Wicked           Gershwin Theatre       2435631.00
# 1       The Outsiders  Bernard B. Jacobs Theatre       1306481.95
# 2       The Lion King           Minskoff Theatre       1543557.10
# 3    The Great Gatsby           Broadway Theatre       1056897.21
# 4  The Book of Mormon     Eugene O'Neill Theatre        835677.45
#
#    AVG TICKET PRICE  TOP TICKET PRICE  SEATS SOLD  SEATS IN THEATER  \
# 0            158.08             352.0       15408              1926
# 1            156.75             497.0        8335              1024
# 2            116.91             267.0       13203              1696
# 3             96.95             277.0       10902              1485
# 4            103.48               0.0        8076              1066
#
#    PERFORMANCES  PREVIEWS  CAPACITY %  WEEK DATE
# 0             8         0      1.0000 2025-03-09
# 1             8         0      1.0175 2025-03-09
# ...

# %%
df1.describe()
# Out:
#        THIS WEEK GROSS  AVG TICKET PRICE  TOP TICKET PRICE    SEATS SOLD  \
# count     5.174300e+04      51743.000000      51116.000000  51743.000000
# mean      6.272656e+05         73.832110        156.781208   7947.935875
# min       0.000000e+00          0.000000          0.000000      0.000000
# 25%       2.869850e+05         45.950000         60.000000   5522.500000
# 50%       5.071020e+05         65.530000        175.000000   7777.000000
# 75%       8.347570e+05         92.540000        249.500000  10265.500000
# max       5.037392e+06        511.580000       1498.000000  24305.000000
# std       4.828468e+05         41.907615        131.865778   3175.157582
#
#        SEATS IN THEATER  PERFORMANCES      PREVIEWS    CAPACITY %  \
# count      51743.000000  51743.000000  51743.000000  51743.000000
# mean        1234.650214      7.228611      0.583171      0.811866
# min            0.000000      0.000000      0.000000      0.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(65,20))
sns.barplot(data=df1.groupby(["THEATER"]).sum("AVG TICKET PRICE"),x="THEATER",y="AVG TICKET PRICE")
# Out:
# <Axes: xlabel='THEATER', ylabel='AVG TICKET PRICE'>

# %%
plt.figure(figsize=(75,20))
sns.barplot(data=df1.groupby(["THEATER"]).sum("AVG TICKET PRICE").reset_index().sort_values(by="AVG TICKET PRICE",
            ascending=False),
            x="THEATER",y="AVG TICKET PRICE")
# Out:
# <Axes: xlabel='THEATER', ylabel='AVG TICKET PRICE'>

# %%
plt.figure(figsize=(15,7))
sns.lineplot(data=df1[df1['SHOW'] == 'Hamilton'],x=df1['WEEK DATE'].dt.year,y=df1['THIS WEEK GROSS'][df1['SHOW'] == 'Hamilton'], color='purple')
plt.title('Hamilton Revenue')
plt.xlabel('Time')
plt.ylabel('Revenue')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lineplot(data=df1[df1['SHOW'] == 'The Lion King'],x=df1['WEEK DATE'].dt.year,y=df1['THIS WEEK GROSS'][df1['SHOW'] == 'The Lion King'], color='red')
plt.title('The Lion King Revenue')
plt.xlabel('Time')
plt.ylabel('Revenue')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lineplot(data=df1[df1['SHOW'] == 'Wicked'],x=df1['WEEK DATE'].dt.year,y=df1['THIS WEEK GROSS'][df1['SHOW'] == 'Wicked'], color='green')
plt.title('Wicked Revenue')
plt.xlabel('Time')
plt.ylabel('Revenue')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lineplot(data=df1[df1['SHOW'] == 'The Phantom of the Opera'],x=df1['WEEK DATE'].dt.year,y=df1['THIS WEEK GROSS'][df1['SHOW'] == 'The Phantom of the Opera'], color='black')
plt.title('The Phantom of the Opera Revenue')
plt.xlabel('Time')
plt.ylabel('Revenue')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lineplot(data=df1[df1['SHOW'] == 'The Book of Mormon'],x=df1['WEEK DATE'].dt.year,y=df1['THIS WEEK GROSS'][df1['SHOW'] == 'The Book of Mormon'], color='blue')
plt.title('The Book of Mormon Revenue')
plt.xlabel('Time')
plt.ylabel('Revenue')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.lineplot(data=df1[df1['SHOW'] == 'Chicago'],x=df1['WEEK DATE'].dt.year,y=df1['THIS WEEK GROSS'][df1['SHOW'] == 'Chicago'], color='blue')
plt.title('Chicago Revenue')
plt.xlabel('Time')
plt.ylabel('Revenue')
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.scatter(data=df1[df1['SHOW'] == 'The Lion King'],x='WEEK DATE',y='THIS WEEK GROSS', color='red')
plt.title('The Lion King Revenue')
plt.xlabel('Time')
plt.ylabel('Revenue')
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.scatter(data=df1[df1['SHOW'] == 'Wicked'],x='WEEK DATE',y='THIS WEEK GROSS', color='green')
plt.title('Wicked Revenue')
plt.xlabel('Time')
plt.ylabel('Revenue')
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.scatter(data=df1[df1['SHOW'] == 'The Phantom of the Opera'],x='WEEK DATE',y='THIS WEEK GROSS', color='black')
plt.title('The Phantom of the Opera Revenue')
plt.xlabel('Time')
plt.ylabel('Revenue')
plt.show()

# %%
Highest_Revenue = df1.groupby('SHOW')['THIS WEEK GROSS'].sum().reset_index().sort_values(
    by='THIS WEEK GROSS', ascending=False)

# %%
Top_Ten = Highest_Revenue.head(10)
plt.figure(figsize=(8,5))
sns.barplot(data=Top_Ten,x='THIS WEEK GROSS',y='SHOW')
plt.show()

# %%
Most_Seats_Filled = df1.groupby('SHOW')['CAPACITY %'].mean().reset_index().sort_values(
    by='CAPACITY %', ascending=False)

# %%
Top_Ten = Most_Seats_Filled.head(30)
plt.figure(figsize=(8,5))
sns.barplot(data=Top_Ten,x='CAPACITY %',y='SHOW')
plt.show()

# %%
Avg_Ticket = df1.groupby('SHOW')['AVG TICKET PRICE'].mean().reset_index().sort_values(
    by='AVG TICKET PRICE', ascending=False
)

# %%
plt.figure(figsize=(8,5))
top_10 = Avg_Ticket.head(10)
sns.barplot(data=top_10, x='AVG TICKET PRICE',y='SHOW')
plt.title('Top Shows by Average Ticket Price')
plt.ylabel('Show Title')
plt.xlabel('Average ticket price by week')
plt.show()

# %%
df2 = pd.read_csv('C:/Users/bradl/Documents/Code/Capstone Project/Potential Datasets/Broadway 10 years.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13436 entries, 0 to 13435
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SHOW              13436 non-null  object
#  1   THEATER           13436 non-null  object
#  2   THIS WEEK GROSS   13436 non-null  object
#  3   AVG TICKET PRICE  13436 non-null  object
#  4   TOP TICKET PRICE  12809 non-null  object
#  5   SEATS SOLD        13436 non-null  object
#  6   SEATS IN THEATER  13436 non-null  object
#  7   PERFORMANCES      13436 non-null  int64
#  8   PREVIEWS          13436 non-null  int64
#  9   CAPACITY %        13436 non-null  object
#  10  WEEK DATE         13436 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.1+ MB

# %%
df2['AVG TICKET PRICE'] = df2['AVG TICKET PRICE'].str.replace('$','')
df2['AVG TICKET PRICE'] = df2['AVG TICKET PRICE'].astype('float64')

# %%
df2['TOP TICKET PRICE'] = df2['TOP TICKET PRICE'].str.replace('$','').str.replace(',','')
df2['TOP TICKET PRICE'] = df2['TOP TICKET PRICE'].astype('float64')

# %%
df2['THIS WEEK GROSS'] = df2['THIS WEEK GROSS'].str.replace('$','').str.replace(',','')
df2['THIS WEEK GROSS'] = df2['THIS WEEK GROSS'].astype('float64')

# %%
df2['SEATS SOLD'] = df2['SEATS SOLD'].str.replace(',','')
df2['SEATS SOLD'] = df2['SEATS SOLD'].astype('int64')

# %%
df2['SEATS IN THEATER'] = df2['SEATS IN THEATER'].str.replace(',','')
df2['SEATS IN THEATER'] = df2['SEATS IN THEATER'].astype('int64')

# %%
df2['CAPACITY %'] = df2['CAPACITY %'].str.rstrip('%').astype(float) / 100

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13436 entries, 0 to 13435
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SHOW              13436 non-null  object
#  1   THEATER           13436 non-null  object
#  2   THIS WEEK GROSS   13436 non-null  float64
#  3   AVG TICKET PRICE  13436 non-null  float64
#  4   TOP TICKET PRICE  12809 non-null  float64
#  5   SEATS SOLD        13436 non-null  int64
#  6   SEATS IN THEATER  13436 non-null  int64
#  7   PERFORMANCES      13436 non-null  int64
#  8   PREVIEWS          13436 non-null  int64
#  9   CAPACITY %        13436 non-null  float64
#  10  WEEK DATE         13436 non-null  object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 1.1+ MB

# %%
df2.head(5)
# Out:
#                  SHOW                    THEATER  THIS WEEK GROSS  \
# 0              Wicked           Gershwin Theatre       2435631.00
# 1       The Outsiders  Bernard B. Jacobs Theatre       1306481.95
# 2       The Lion King           Minskoff Theatre       1543557.10
# 3    The Great Gatsby           Broadway Theatre       1056897.21
# 4  The Book of Mormon     Eugene O'Neill Theatre        835677.45
#
#    AVG TICKET PRICE  TOP TICKET PRICE  SEATS SOLD  SEATS IN THEATER  \
# 0            158.08             352.0       15408              1926
# 1            156.75             497.0        8335              1024
# 2            116.91             267.0       13203              1696
# 3             96.95             277.0       10902              1485
# 4            103.48               0.0        8076              1066
#
#    PERFORMANCES  PREVIEWS  CAPACITY % WEEK DATE
# 0             8         0      1.0000  3/9/2025
# 1             8         0      1.0175  3/9/2025
# ...

# %%
df2['WEEK DATE'] = pd.to_datetime(df2['WEEK DATE'])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13436 entries, 0 to 13435
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SHOW              13436 non-null  object
#  1   THEATER           13436 non-null  object
#  2   THIS WEEK GROSS   13436 non-null  float64
#  3   AVG TICKET PRICE  13436 non-null  float64
#  4   TOP TICKET PRICE  12809 non-null  float64
#  5   SEATS SOLD        13436 non-null  int64
#  6   SEATS IN THEATER  13436 non-null  int64
#  7   PERFORMANCES      13436 non-null  int64
#  8   PREVIEWS          13436 non-null  int64
#  9   CAPACITY %        13436 non-null  float64
#  10  WEEK DATE         13436 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(4), object(2)
# memory usage: 1.1+ MB

# %%
grouped_by_year = df2.groupby(df2['WEEK DATE'].dt.year)

# %%
grouped_by_year

# %%
grouped_by_year.head(5)
# Out:
#                                                     SHOW  \
# 0                                                 Wicked
# 1                                          The Outsiders
# 2                                          The Lion King
# 3                                       The Great Gatsby
# 4                                     The Book of Mormon
# 284                                               Wicked
# 285                                        The Outsiders
# 286                                        The Lion King
# 287                                     The Great Gatsby
# 288                                   The Book of Mormon
# 1872                                            & Juliet
# 1873                                             Aladdin
# 1874                                         Appropriate
# 1875                                  Back To The Future
# 1876         A Beautiful Noise, The Neil Diamond Musical
# ...

# %%
yearly_totals = grouped_by_year['THIS WEEK GROSS'].sum()

# %%
print(yearly_totals)
# Out:
# WEEK DATE
# 2015    1.139241e+09
# 2016    1.367274e+09
# 2017    1.629971e+09
# 2018    1.821343e+09
# 2019    1.754273e+09
# 2020    2.980676e+08
# 2021    3.244987e+08
# 2022    1.434567e+09
# 2023    1.604169e+09
# 2024    1.691457e+09
# 2025    3.151324e+08
# Name: THIS WEEK GROSS, dtype: float64

# %%
sns.histplot(yearly_totals)
# Out:
# <Axes: xlabel='THIS WEEK GROSS', ylabel='Count'>

# %%
Most_Seats_Filled = df2.groupby('SHOW')['CAPACITY %'].mean().reset_index().sort_values(
    by='CAPACITY %', ascending=False)

# %%
Top_Ten = Most_Seats_Filled.head(20)
plt.figure(figsize=(8,5))
sns.barplot(data=Top_Ten,x='CAPACITY %',y='SHOW')
plt.show()

# %%
Highest_Revenue = df2.groupby('SHOW')['THIS WEEK GROSS'].sum().reset_index().sort_values(
    by='THIS WEEK GROSS', ascending=False)

# %%
Top_Ten = Highest_Revenue.head(10)
plt.figure(figsize=(8,5))
sns.barplot(data=Top_Ten,x='THIS WEEK GROSS',y='SHOW')
plt.show()
